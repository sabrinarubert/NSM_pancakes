# %% [markdown]
# ## API New York Times
#
# ### Data from NYT Best Sellers List

# %%
import pandas as pd
import requests
import json
import time

apikey = "GpGQ5K8J787inp2xIfGHnusXBCtNfeJe"

# selected categories that are still dislpayed
validListNames = ['combined-print-and-e-book-fiction'
,'combined-print-and-e-book-nonfiction'
,'hardcover-fiction'
,'hardcover-nonfiction'
,'trade-fiction-paperback'
,'paperback-nonfiction'
,'advice-how-to-and-miscellaneous'
,'childrens-middle-grade-hardcover'
,'picture-books'
,'series-books'
,'young-adult-hardcover'
,'audio-fiction'
,'audio-nonfiction'
,'business-books'
,'graphic-books-and-manga'
,'mass-market-monthly'
,'middle-grade-paperback-monthly'
,'young-adult-paperback-monthly']

# adding month
def addOneMonth(date):
    try:
        newDate = date.replace(month=date.month+1)
    except ValueError:
        if date.month == 12:
            newDate = date.replace(year=date.year+1, month=1)
        else:
    # next month is too short to have "same date"
    # pick your own heuristic, or re-raise the exception:
            raise
    
    return newDate

#/lists/names.json
print("https://api.nytimes.com/svc/books/v3/lists/names.json?api-key="+apikey)

# get all lists available
listResponse = requests.get("https://api.nytimes.com/svc/books/v3/lists/names.json?api-key="+apikey)

# create daraframe results json object
listDataFrame = pd.DataFrame(listResponse.json()["results"])

# change datatype (string to date)
listDataFrame['oldest_published_date'] = listDataFrame['oldest_published_date'].astype('datetime64[ns]')
listDataFrame['newest_published_date'] = listDataFrame['newest_published_date'].astype('datetime64[ns]')

# save list of all available categories to csv
listDataFrame.to_csv("lists.csv", index=False)

# filter dataframe with selected categories
filteredListDataFrame = listDataFrame[listDataFrame['list_name_encoded'].isin(validListNames)]

# initialize variable for dataframe
result = None

# iterate through dataframe with selected categories 
for index, row in filteredListDataFrame.iterrows():
    
    # get list name from row
    list_name_encoded     = row['list_name_encoded']
    
    # get published dates from row
    oldest_published_date = row['oldest_published_date']
    newest_published_date = row['newest_published_date']
    
    # adjust publish date to entire month (to have a monthly overview)
    oldest_published_date_cleaned = addOneMonth(oldest_published_date)
    oldest_published_date_cleaned = oldest_published_date.replace(day=1)
    newest_published_date_cleaned = newest_published_date.replace(day=1)
    
    # set starting date for request )
    requestDate = oldest_published_date_cleaned
    
    # iterate over all months between oldes and newest published dates for selected categories
    while requestDate < newest_published_date_cleaned:
        requestDate = addOneMonth(requestDate)

        #/lists/{date}/{list}.json
        print("https://api.nytimes.com/svc/books/v3/lists/"+requestDate.strftime('%Y-%m-%d')+"/"+list_name_encoded+".json?api-key="+apikey)
        bestsellerResponse = requests.get("https://api.nytimes.com/svc/books/v3/lists/"+requestDate.strftime('%Y-%m-%d')+"/"+list_name_encoded+".json?api-key="+apikey)
        
        # new dataframe with bestseller books from selected categories
        bestsellerDataFrame = pd.DataFrame(bestsellerResponse.json()["results"]["books"])
        
        # add new columns for list(category) and date when book is ranked
        bestsellerDataFrame["list"] = list_name_encoded
        bestsellerDataFrame["date"] = requestDate
        
        # delete columns that are not useful
        bestsellerDataFrame = bestsellerDataFrame.drop(columns=['asterisk', 'dagger', 'contributor','contributor_note', 'book_image','book_image_width', 'book_image_height', 'amazon_product_url','first_chapter_link','sunday_review_link', 'article_chapter_link', 'book_review_link', 'buy_links', 'book_uri', 'isbns', 'rank_last_week', 'weeks_on_list', 'primary_isbn10'])

        # save dataframe
        if (result is None):
            result = bestsellerDataFrame
        else:
            result = result.append(bestsellerDataFrame)  
        
        # identify unique books
        uniqueIsbns = result['primary_isbn13'].unique()
        for isbn in uniqueIsbns:
            
            # count how many months is book on bestseller list
            length = result.loc[result['primary_isbn13'] == isbn].shape[0]          
            result.loc[result['primary_isbn13'] == isbn, 'month_on_list'] = int(length)
        
        # create csv with final results
        result.to_csv("result.csv", index=False)
        
        # set timer to avoid rate limit
        time.sleep(6)
# Out:
# https://api.nytimes.com/svc/books/v3/lists/names.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-03-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-04-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-05-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-06-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-07-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-08-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-09-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-10-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-11-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-12-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-01-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-02-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-03-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-04-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-05-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-06-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-07-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-08-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-09-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-10-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-11-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-12-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2013-01-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2013-02-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2013-03-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2013-04-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2013-05-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2013-06-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2013-07-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2013-08-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2013-09-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2013-10-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2013-11-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2013-12-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2014-01-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2014-02-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2014-03-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2014-04-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2014-05-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2014-06-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2014-07-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2014-08-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2014-09-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2014-10-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2014-11-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2014-12-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2015-01-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2015-02-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2015-03-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2015-04-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2015-05-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2015-06-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2015-07-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2015-08-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2015-09-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2015-10-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2015-11-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2015-12-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2016-01-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2016-02-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2016-03-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2016-04-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2016-05-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2016-06-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2016-07-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2016-08-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2016-09-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2016-10-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2016-11-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2016-12-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2017-01-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2017-02-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2017-03-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2017-04-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2017-05-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2017-06-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2017-07-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2017-08-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2017-09-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2017-10-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2017-11-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2017-12-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2018-01-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2018-02-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2018-03-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2018-04-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2018-05-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2018-06-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2018-07-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2018-08-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2018-09-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2018-10-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2018-11-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2018-12-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-01-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-02-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-03-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-04-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-05-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-06-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-07-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-08-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-09-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-10-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-11-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-12-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2020-01-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2020-02-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2020-03-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2020-04-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2020-05-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2020-06-01/combined-print-and-e-book-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-03-01/combined-print-and-e-book-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-04-01/combined-print-and-e-book-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-05-01/combined-print-and-e-book-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-06-01/combined-print-and-e-book-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-07-01/combined-print-and-e-book-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-08-01/combined-print-and-e-book-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-09-01/combined-print-and-e-book-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-10-01/combined-print-and-e-book-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-11-01/combined-print-and-e-book-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-12-01/combined-print-and-e-book-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-01-01/combined-print-and-e-book-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-02-01/combined-print-and-e-book-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-03-01/combined-print-and-e-book-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-04-01/combined-print-and-e-book-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-05-01/combined-print-and-e-book-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-06-01/combined-print-and-e-book-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-07-01/combined-print-and-e-book-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-08-01/combined-print-and-e-book-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/
01/hardcover-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-06-01/hardcover-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-07-01/hardcover-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-08-01/hardcover-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-09-01/hardcover-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-10-01/hardcover-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-11-01/hardcover-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-12-01/hardcover-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2020-01-01/hardcover-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2020-02-01/hardcover-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2020-03-01/hardcover-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2020-04-01/hardcover-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2020-05-01/hardcover-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2020-06-01/hardcover-fiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2008-07-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2008-08-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2008-09-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2008-10-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# ...
# https://api.nytimes.com/svc/books/v3/lists/2010-11-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2010-12-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-01-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-02-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-03-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-04-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-05-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-06-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-07-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-08-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-09-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-10-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-11-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2011-12-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-01-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-02-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-03-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-04-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-05-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-06-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-07-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-08-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-09-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-10-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-11-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2012-12-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2013-01-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2013-02-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2013-03-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2013-04-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2013-05-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2013-06-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2013-07-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2013-08-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2013-09-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2013-10-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2013-11-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2013-12-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2014-01-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2014-02-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2014-03-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2014-04-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2014-05-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2014-06-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2014-07-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2014-08-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2014-09-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2014-10-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2014-11-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2014-12-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2015-01-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2015-02-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2015-03-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2015-04-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2015-05-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2015-06-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2015-07-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2015-08-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2015-09-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2015-10-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2015-11-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2015-12-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2016-01-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2016-02-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2016-03-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2016-04-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2016-05-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2016-06-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2016-07-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2016-08-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2016-09-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2016-10-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2016-11-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2016-12-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2017-01-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2017-02-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2017-03-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2017-04-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2017-05-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2017-06-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2017-07-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2017-08-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2017-09-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2017-10-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2017-11-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2017-12-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2018-01-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2018-02-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2018-03-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2018-04-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2018-05-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2018-06-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2018-07-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2018-08-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2018-09-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2018-10-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2018-11-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2018-12-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-01-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-02-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-03-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-04-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-05-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-06-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-07-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-08-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-09-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-10-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-11-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2019-12-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2020-01-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2020-02-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2020-03-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2020-04-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2020-05-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# https://api.nytimes.com/svc/books/v3/lists/2020-06-01/hardcover-nonfiction.json?api-key=GpGQ5K8J787inp2xIfGHnusXBCtNfeJe
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-65-917755c01a2f> in <module>
#      71         bestsellerResponse = requests.get("https://api.nytimes.com/svc/books/v3/lists/"+requestDate.strftime('%Y-%m-%d')+"/"+list_name_encoded+".json?api-key="+apikey)
#      72
# ---> 73         bestsellerDataFrame = pd.DataFrame(bestsellerResponse.json()["results"]["books"])
#      74         bestsellerDataFrame["list"] = list_name_encoded
#      75         bestsellerDataFrame["date"] = requestDate
#
# /opt/anaconda3/envs/boogie_woogie/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# /opt/anaconda3/envs/boogie_woogie/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# /opt/anaconda3/envs/boogie_woogie/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /opt/anaconda3/envs/boogie_woogie/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
